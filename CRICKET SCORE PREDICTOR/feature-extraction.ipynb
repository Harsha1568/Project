# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#            city                     venue
# 0           NaN  Melbourne Cricket Ground
# ...

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# ...

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# ...

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# ...

# %%
df['current_score'] = df.groupby('match_id').cumsum()['runs']
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df['current_score'] = df.groupby('match_id').cumsum()['runs']
#
# File G:\coding\Lib\site-packages\pandas\core\groupby\groupby.py:4936, in GroupBy.cumsum(self, axis, *args, **kwargs)
#    4933     f = lambda x: x.cumsum(axis=axis, **kwargs)
#    4934     return self._python_apply_general(f, self._selected_obj, is_transform=True)
# -> 4936 return self._cython_transform("cumsum", **kwargs)
#
# File G:\coding\Lib\site-packages\pandas\core\groupby\generic.py:1702, in DataFrameGroupBy._cython_transform(self, how, numeric_only, axis, **kwargs)
#    1696     return self._grouper._cython_operation(
#    1697         "transform", bvalues, how, 1, **kwargs
#    1698     )
#    1700 # We could use `mgr.apply` here and not have to set_axis, but
# ...

# %%
# Ensure 'runs' column is numeric
df['runs'] = pd.to_numeric(df['runs'], errors='coerce')

# Apply the cumsum operation within each group
df['current_score'] = df.groupby('match_id')['runs'].cumsum()
# Out:
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_7268\400241622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['runs'] = pd.to_numeric(df['runs'], errors='coerce')
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_7268\400241622.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score
# 0       Melbourne              0
# 1       Melbourne              0
# ...

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_7268\2777558413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_7268\2777558413.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# ...

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_7268\562775579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# ...

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_7268\2304996896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_7268\2304996896.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# ...

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_7268\540685528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_7268\540685528.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# ---------------------------------------------------------------------------
# ...

# %%
# Convert 'player_dismissed' to 0 or 1
df['player_dismissed'] = df['player_dismissed'].apply(lambda x: 0 if x == '0' else 1)

# Ensure 'player_dismissed' is of integer type
df['player_dismissed'] = df['player_dismissed'].astype(int)

# Verify the dtype
print(df['player_dismissed'].dtype)  # Should print 'int32' or 'int64'

# Apply cumsum within each group
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()

# Calculate wickets left
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# int64
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_7268\456855733.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x: 0 if x == '0' else 1)
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_7268\456855733.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype(int)
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_7268\456855733.py:11: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 1
# 1              2    Australia    Sri Lanka   0.2     0                 2
# 2              2    Australia    Sri Lanka   0.3     1                 3
# 3              2    Australia    Sri Lanka   0.4     2                 4
# 4              2    Australia    Sri Lanka   0.5     0                 5
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1               122
# 115321       964    Sri Lanka    Australia  19.4     0               123
# 115322       964    Sri Lanka    Australia  19.5     0               124
# 115323       964    Sri Lanka    Australia  19.6     2               125
# 115324       964    Sri Lanka    Australia  19.7     1               126
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_7268\914577034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 1
# 1              2    Australia    Sri Lanka   0.2     0                 2
# 2              2    Australia    Sri Lanka   0.3     1                 3
# 3              2    Australia    Sri Lanka   0.4     2                 4
# 4              2    Australia    Sri Lanka   0.5     0                 5
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1               122
# 115321       964    Sri Lanka    Australia  19.4     0               123
# 115322       964    Sri Lanka    Australia  19.5     0               124
# 115323       964    Sri Lanka    Australia  19.6     2               125
# 115324       964    Sri Lanka    Australia  19.7     1               126
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File G:\coding\Lib\site-packages\pandas\core\window\rolling.py:371, in BaseWindow._prep_values(self, values)
#     370     else:
# --> 371         values = ensure_float64(values)
#     372 except (ValueError, TypeError) as err:
#
# File pandas\\_libs\\algos_common_helper.pxi:42, in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: 'Australia'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# File G:\coding\Lib\site-packages\pandas\core\window\rolling.py:489, in BaseWindow._apply_columnwise(self, homogeneous_func, name, numeric_only)
#     488 try:
# --> 489     arr = self._prep_values(arr)
#     490 except (TypeError, NotImplementedError) as err:
#
# ...

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    group = groups.get_group(id)
    # Ensure 'runs' column is numeric, coerce invalid values to NaN and then drop them
    group['runs'] = pd.to_numeric(group['runs'], errors='coerce')
    group = group.dropna(subset=['runs'])
    last_five.extend(group.rolling(window=30).sum()['runs'].values.tolist())
# Out:
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_7268\2273769975.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group['runs'] = pd.to_numeric(group['runs'], errors='coerce')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File G:\coding\Lib\site-packages\pandas\core\window\rolling.py:371, in BaseWindow._prep_values(self, values)
#     370     else:
# --> 371         values = ensure_float64(values)
#     372 except (ValueError, TypeError) as err:
#
# File pandas\\_libs\\algos_common_helper.pxi:42, in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: 'Australia'
#
# ...

# %%
groups = df.groupby('match_id')
match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    group = groups.get_group(id)
    group['runs'] = pd.to_numeric(group['runs'], errors='coerce')
    clean_group = group.dropna(subset=['runs'])
    rolling_sum = clean_group.rolling(window=30).sum()['runs']
    last_five.extend(rolling_sum.values.tolist())
# Out:
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_7268\4091320928.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   group['runs'] = pd.to_numeric(group['runs'], errors='coerce')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File G:\coding\Lib\site-packages\pandas\core\window\rolling.py:371, in BaseWindow._prep_values(self, values)
#     370     else:
# --> 371         values = ensure_float64(values)
#     372 except (ValueError, TypeError) as err:
#
# File pandas\\_libs\\algos_common_helper.pxi:42, in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: 'Australia'
#
# ...

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File G:\coding\Lib\site-packages\pandas\core\window\rolling.py:371, in BaseWindow._prep_values(self, values)
#     370     else:
# --> 371         values = ensure_float64(values)
#     372 except (ValueError, TypeError) as err:
#
# File pandas\\_libs\\algos_common_helper.pxi:42, in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: 'Australia'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# File G:\coding\Lib\site-packages\pandas\core\window\rolling.py:489, in BaseWindow._apply_columnwise(self, homogeneous_func, name, numeric_only)
#     488 try:
# --> 489     arr = self._prep_values(arr)
#     490 except (TypeError, NotImplementedError) as err:
#
# ...

# %%
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    group = groups.get_group(id).copy()  # Make an explicit copy to avoid the SettingWithCopyWarning
    
    # Convert 'runs' to numeric, coercing errors, and filter out non-numeric rows
    group.loc[:, 'runs'] = pd.to_numeric(group['runs'], errors='coerce')
    
    # Drop rows where 'runs' is NaN after conversion
    group = group.dropna(subset=['runs'])
    
    # Apply rolling sum only on the cleaned data
    rolling_sum = group['runs'].rolling(window=30).sum()
    
    # Extend the result to the last_five list
    last_five.extend(rolling_sum.values.tolist())

# %%
df['last_five'] = last_five
# Out:
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_7268\1595651733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                 1
# 1              2    Australia    Sri Lanka   0.2     0                 2
# 2              2    Australia    Sri Lanka   0.3     1                 3
# 3              2    Australia    Sri Lanka   0.4     2                 4
# 4              2    Australia    Sri Lanka   0.5     0                 5
# ...          ...          ...          ...   ...   ...               ...
# 115320       964    Sri Lanka    Australia  19.3     1               122
# 115321       964    Sri Lanka    Australia  19.4     0               123
# 115322       964    Sri Lanka    Australia  19.5     0               124
# 115323       964    Sri Lanka    Australia  19.6     2               125
# 115324       964    Sri Lanka    Australia  19.7     1               126
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(2)
# Out:
#        batting_team bowling_team          city  current_score  balls_left  \
# 45433     Sri Lanka      England   Southampton            140           2
# 6670   South Africa     Pakistan  Johannesburg            114          31
#
#        wickets_left       crr  last_five  runs_x
# 45433          -111  7.118644       32.0     140
# 6670            -81  7.685393       53.0     188

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[39], line 3
#       1 X = final_df.drop(columns=['runs_x'])
#       2 y = final_df['runs_x']
# ----> 3 from sklearn.model_selection import train_test_split
#       4 X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        batting_team bowling_team         city  current_score  balls_left  \
# 3353    Afghanistan  West Indies     St Kitts            110           0
# 45404     Sri Lanka      England  Southampton            109          31
# 48398  South Africa  West Indies       Nagpur             70          52
# 18119         India    Australia    Melbourne             62          30
# 27877   New Zealand    Sri Lanka   Lauderhill             82          33
# ...             ...          ...          ...            ...         ...
# 2767     Bangladesh    Sri Lanka      Colombo             50          92
# 8742       Pakistan  New Zealand    Abu Dhabi             31          83
# 46386   West Indies    Sri Lanka      Colombo            104          41
# 49985      Pakistan   Bangladesh       Mirpur             42          52
# 15195   West Indies      England       London             66          83
#
#        wickets_left        crr  last_five
# 3353           -112   5.500000       48.0
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 trf = ColumnTransformer([
# ----> 2     ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
#       3 ]
#       4 ,remainder='passthrough')
#
# TypeError: OneHotEncoder.__init__() got an unexpected keyword argument 'sparse'

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'city'])
], remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9818676710128784
# 1.978884606748014

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
eligible_cities
# Out:
# ['Colombo',
#  'Mirpur',
#  'Johannesburg',
#  'Dubai',
#  'Auckland',
#  'Cape Town',
#  'London',
#  'Pallekele',
#  'Barbados',
#  'Sydney',
#  'Melbourne',
#  'Durban',
#  'St Lucia',
#  'Wellington',
#  'Lauderhill',
#  'Hamilton',
#  'Centurion',
#  'Manchester',
#  'Abu Dhabi',
#  'Mumbai',
#  'Nottingham',
#  'Southampton',
#  'Mount Maunganui',
#  'Chittagong',
#  'Kolkata',
#  'Lahore',
#  'Delhi',
#  'Nagpur',
#  'Chandigarh',
#  'Adelaide',
#  'Bangalore',
#  'St Kitts',
#  'Cardiff',
#  'Christchurch',
#  'Trinidad']
